# %% [markdown]
# ## Welcome
#
# In this lab, you will build a complete machine learning application — from raw data to interactive visualisations — using IBM Bob as your AI coding assistant.
#
# ### Lab overview
#
# This lab shows you how to analyze historical space weather data and build a predictive model that estimates launch safety risk levels. The focus is on using Bob to scaffold Python code and running prebuilt models, making this lab achievable for beginners with copy-paste-and-run instructions.
#
# **Estimated time:** 60–90 minutes
#
# ### Prerequisites
#
# - IBM Bob installed and configured
# - Python environment with Jupyter Lab installed and configured
# - Basic familiarity with running code cells in Jupyter notebooks

# %% [markdown]
# ---
#
# ## Contents
#
# - [Task 1: Install required Python libraries.](#task1)
#
# - [Task 2: Download the dataset.](#task2)
#
# - [Task 3: Prepare the data.](#task3)
#
# - [Task 4: Explore and analyze the data.](#task4)
#
# - [Task 5: Add feature engineering for risk assessment.](#task5)
#
# - [Task 6: Create risk scoring model.](#task6)
#
# - [Task 7: Train and evaluate decision model.](#task7)
#
# - [Task 8: Save model and risk data.](#task8)
#
# - [Task 9: Build a date-range go/no-go dashboard.](#task9)
#
#
# ---
#
# ## Complete the lab
#
# Follow these steps to set up your environment and complete the lab:
#
# 1. Follow the instructions in the lab guide to install and open IBM Bob on your machine.
# 3. Open Bob's chat panel on the right side.
# 4. Select **Agent** mode.
# 5. For each task, copy the provided prompt into Bob's chat panel.
# 6. Paste Bob's generated code into the empty code cell.
# 7. Press **Shift + Enter** or click the **Run** icon to execute the cell.
# 8. If the code fails, run the fallback cell instead.
#
# Each task includes:
# - An objective describing what you will accomplish
# - A prompt to provide to Bob
# - An empty cell for Bob's code
# - A fallback code cell with working code
#
# ---

# %% [markdown]
# <a id="task1"></a>
# ## Task 1: Install required Python libraries
#
# **Objective:** Install and verify the Python libraries needed for this lab: pandas, nupy, scikit-learn, matplotlib, Streamlit, joblib, and requests.
#
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# I am going to provide you with a number of prompts asking to generate code for me. I suggest you create that code in a separate jupyter lab file. You may use name bob_generated_code.ipynb. First prompt is below:
#
# In the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 1: Install required Python libraries", and for the second cell, generate the code based on the following prompt:
#
# Write the code for a single Jupyter notebook cell that uses the %pip install -q magic (not !pip, not subprocess) to install pandas, numpy, scikit-learn, matplotlib, streamlit, joblib, and requests. Then import them with aliases (pandas as pd, numpy as np; the rest without aliases) and print each version using __version__ with the format 'name:       version' left-aligned so the version values line up. Use the following exact labels and spacing:
#   pandas:       {pd.__version__}
#   numpy:        {np.__version__}
#   scikit-learn: {sklearn.__version__}
#   matplotlib:   {matplotlib.__version__}
#   streamlit:    {streamlit.__version__}
#   joblib:       {joblib.__version__}
#   requests:     {requests.__version__}
# Print nothing else.
# ```

# %% [markdown]
# ### What Bob does
# - Generate a file with name bob_generated_code.ipynb. This file can be viewed as plain JSON and as Jupyter lab code.
# - Add the generated code as a new cell at the end of the bob_generated_code.ipynb file for subsequent prompts.
#
# ### Execute Bob's code
#
# 1. Double-click the bob_generated_code.ipynb file in the Jupyter Lab explorer panel to see the generated code.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
# %pip install -q pandas numpy scikit-learn matplotlib streamlit joblib requests

import pandas as pd
import numpy as np
import sklearn
import matplotlib
import streamlit
import joblib
import requests

print(f"pandas:       {pd.__version__}")
print(f"numpy:        {np.__version__}")
print(f"scikit-learn: {sklearn.__version__}")
print(f"matplotlib:   {matplotlib.__version__}")
print(f"streamlit:    {streamlit.__version__}")
print(f"joblib:       {joblib.__version__}")
print(f"requests:     {requests.__version__}")

# %% [markdown]
# <a id="task2"></a>
# ## Task 2: Download the dataset
#
# **Objective:** Fetch the Space results dataset from GitHub, load it into a pandas DataFrame, and verify the data.

# %% [markdown]
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 2: Download the dataset", and for the second cell, generate the code based on the following prompt:
#
# Use pathlib.Path to create a data/ folder in the current working directory (use Path("data").mkdir(exist_ok=True), not os.makedirs).
# Download LINKPLACEHOLDER to data/space_weather_unified.csv using the requests library — but only if that file doesn't already exist locally. If the file already exists, print 'Using cached data/space_weather_unified.csv'. If it does not exist, download it, print a download message, then print the saved file size in KB.
# Load data/space_weather_unified.csv into a pandas DataFrame named matches using pd.read_csv() with parse_dates=['date'].
# Print matches.shape as 'Shape: (rows, cols)', then print the min and max of the date column as 'Date range: YYYY-MM-DD → YYYY-MM-DD'.
# Finally display matches.head(3) as the cell's return value.
#
# Do not use wget, curl, urllib, os.system, or any shell commands. Use only pathlib, requests, and pandas.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. The output generated by Bob's code should be approximately 90% similar to this output.

# %%
from pathlib import Path
import requests
import pandas as pd

data_dir = Path("data")
data_dir.mkdir(exist_ok=True)

csv_path = data_dir / "space_weather_unified.csv"
url = "LINKPLACEHOLDER"

if not csv_path.exists():
    print(f"Downloading {url} ...")
    r = requests.get(url, timeout=30)
    r.raise_for_status()
    csv_path.write_bytes(r.content)
    print(f"Saved {csv_path.stat().st_size / 1024:.1f} KB to {csv_path}")
else:
    print(f"Using cached {csv_path}")

matches = pd.read_csv(csv_path, parse_dates=["date"])
print(f"Shape: {matches.shape}")
print(f"Date range: {matches['date'].min().date()} → {matches['date'].max().date()}")
matches.head(3)

# %% [markdown]
# <a id="task3"></a>
# ## Task 3: Prepare the data
#
# **Objective:** Clean and prepare the space weather dataset by handling missing values, removing duplicates, standardizing data types, and ensuring data quality for analysis.

# %% [markdown]
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 3: Prepare the data", and for the second cell, generate the code based on the following prompt:
#
# Import pandas as pd and numpy as np. Load data/space_weather_unified.csv into a pandas DataFrame named space_df using pd.read_csv() (no parse_dates). Then perform comprehensive data cleaning:
#
# 1. Display initial data info with header '=== Initial Data Info ===': print shape as 'Shape: (rows, cols)', then print 'Columns and Data Types:' followed by space_df.dtypes.to_string(), then print 'First 3 rows:' followed by space_df.head(3).to_string().
#
# 2. Analyze missing values with header '=== Missing Values Analysis ===': create a DataFrame with columns 'Missing_Count' and 'Percentage' (rounded to 2 decimals) for each column, filter to only columns with missing data, sort descending by Missing_Count, and print using .to_string().
#
# 3. Print header '=== Data Cleaning ===' then record initial_rows = len(space_df). Handle missing values:
#    - kp_index: fillna(0.0)
#    - class_type: fillna('Unknown')
#    - source_location: fillna('Unknown')
#    - active_region: fillna('Unknown')
#    - note: fillna('')
#    - observed_time and source: leave as-is
#
# 4. Count duplicates with space_df.duplicated(subset=['event_id']).sum(), then drop duplicates on event_id keeping first. Store count in duplicates_count.
#
# 5. Convert begin_time, peak_time, end_time, observed_time to datetime using pd.to_datetime with errors='coerce'. Leave date column as-is.
#
# 6. Overwrite the year, month, and hour columns by extracting from begin_time using .dt.year/.dt.month/.dt.hour, filling NaN with 0 and casting to int. Also compute:
#    - duration_minutes: (end_time - begin_time).dt.total_seconds() / 60, fillna(0.0)
#    - flare_magnitude and flare_class: define a helper function extract_flare_info(row) that returns a pd.Series({'flare_magnitude': ..., 'flare_class': ...}). For Solar Flare rows where class_type is not NaN and not 'Unknown': extract the first character as flare_class, and extract digits/dots from the rest as float for flare_magnitude (use a try/except, default 0.0). For all other rows return flare_magnitude=0.0, flare_class='N/A'. Apply with axis=1 and assign both columns at once.
#
# 7. Print: 'Initial rows: {initial_rows:,}', 'Duplicates removed: {duplicates_count:,}', 'Final rows: {final_rows:,}'. Then print 'Remaining missing values:' and check space_df.isnull().sum() for columns with count > 0. If any remain print them with .to_string(); if none remain in the key columns print 'No missing values in key columns (kp_index, class_type, source_location, active_region, note)'.
#
# 8. Print '=== First 3 Rows After Cleaning ===' then return space_df.head(3) as the cell's last expression.
#
# Use only pandas and numpy. Do not modify the original CSV file. Store the cleaned data in space_df.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
import pandas as pd
import numpy as np

# Load the dataset
space_df = pd.read_csv('data/space_weather_unified.csv')

print("=== Initial Data Info ===")
print(f"Shape: {space_df.shape}")
print(f"\nColumns and Data Types:")
print(space_df.dtypes.to_string())
print(f"\nFirst 3 rows:")
print(space_df.head(3).to_string())

print("\n=== Missing Values Analysis ===")
missing_counts = space_df.isnull().sum()
missing_pct = (missing_counts / len(space_df) * 100).round(2)
missing_df = pd.DataFrame({
    'Missing_Count': missing_counts,
    'Percentage': missing_pct
})
missing_df = missing_df[missing_df['Missing_Count'] > 0].sort_values('Missing_Count', ascending=False)
print(missing_df.to_string())

print("\n=== Data Cleaning ===")
initial_rows = len(space_df)

# Handle missing values
space_df['kp_index'] = space_df['kp_index'].fillna(0.0)
space_df['class_type'] = space_df['class_type'].fillna('Unknown')
space_df['source_location'] = space_df['source_location'].fillna('Unknown')
space_df['active_region'] = space_df['active_region'].fillna('Unknown')
space_df['note'] = space_df['note'].fillna('')

# Remove duplicates
duplicates_count = space_df.duplicated(subset=['event_id']).sum()
space_df = space_df.drop_duplicates(subset=['event_id'], keep='first')

# Convert datetime columns
datetime_cols = ['begin_time', 'peak_time', 'end_time', 'observed_time']
for col in datetime_cols:
    space_df[col] = pd.to_datetime(space_df[col], errors='coerce')

# Extract year, month, hour from begin_time
space_df['year']  = space_df['begin_time'].dt.year.fillna(0).astype(int)
space_df['month'] = space_df['begin_time'].dt.month.fillna(0).astype(int)
space_df['hour']  = space_df['begin_time'].dt.hour.fillna(0).astype(int)

# Calculate duration in minutes
space_df['duration_minutes'] = (space_df['end_time'] - space_df['begin_time']).dt.total_seconds() / 60
space_df['duration_minutes'] = space_df['duration_minutes'].fillna(0.0)

# Extract flare magnitude and class
def extract_flare_info(row):
    if row['event_type'] == 'Solar Flare' and pd.notna(row['class_type']) and row['class_type'] != 'Unknown':
        class_str = str(row['class_type'])
        # Extract letter class (first character)
        flare_class = class_str[0] if class_str else 'N/A'
        # Extract numeric magnitude
        try:
            magnitude_str = ''.join(c for c in class_str if c.isdigit() or c == '.')
            magnitude = float(magnitude_str) if magnitude_str else 0.0
        except:
            magnitude = 0.0
        return pd.Series({'flare_magnitude': magnitude, 'flare_class': flare_class})
    return pd.Series({'flare_magnitude': 0.0, 'flare_class': 'N/A'})

space_df[['flare_magnitude', 'flare_class']] = space_df.apply(extract_flare_info, axis=1)

final_rows = len(space_df)

print(f"Initial rows: {initial_rows:,}")
print(f"Duplicates removed: {duplicates_count:,}")
print(f"Final rows: {final_rows:,}")
print(f"\nRemaining missing values:")
remaining_missing = space_df.isnull().sum()
remaining_missing = remaining_missing[remaining_missing > 0]
if len(remaining_missing) > 0:
    print(remaining_missing.to_string())
else:
    print("No missing values in key columns (kp_index, class_type, source_location, active_region, note)")

print("\n=== First 3 Rows After Cleaning ===")
space_df.head(3)

# %% [markdown]
# <a id="task4"></a>
# ## Task 4: Explore and analyze the data
#
# **Objective:** Analyze the cleaned space weather dataset to understand patterns, distributions, and relationships between different event types and their characteristics.

# %% [markdown]
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 4: Explore and analyze the data", and for the second cell, generate the code based on the following prompt:
#
# Import pandas as pd, numpy as np, and matplotlib.pyplot as plt. Using the cleaned pandas DataFrame space_df (with columns: event_type, year, month, hour, flare_class, flare_magnitude, duration_minutes, kp_index, class_type), do the following:
#
# PART A – Print statistics (use only pandas and numpy):
# 1. Print header '=== 1. Event Type Distribution ===' then a DataFrame with columns 'Count' and 'Percentage' (2 decimals) per event_type sorted descending by count, printed with .to_string().
# 2. Print header '=== 2. Temporal Summary ===' then 'Events per Year:' followed by value_counts sorted by index, 'Events per Month:' followed by value_counts sorted by index, 'Events per Hour:' followed by value_counts sorted by index. All printed with .to_string().
# 3. Print header '=== 3. Solar Flare Summary ===' then 'Total Solar Flares: {n:,}', 'Flare Class Distribution:' from value_counts() (not sorted by index), flare magnitude stats as 'Flare Magnitude — Mean: X, Median: X, Min: X, Max: X' (2 decimals) for rows where flare_magnitude > 0, duration stats as 'Duration (min)   — Mean: X, Median: X, Min: X, Max: X' (2 decimals) for rows where duration_minutes > 0.
# 4. Print header '=== 4. Geomagnetic Storm Summary ===' then 'Total Geomagnetic Storms: {n:,}', 'Storm Class Distribution:' from class_type value_counts(), and if kp_index > 0 values exist print 'Kp Index — Mean: X, Median: X, Min: X, Max: X' (2 decimals), else print 'No Kp index data available'.
#
# PART B – Create a 2x2 matplotlib figure with fig, axes = plt.subplots(2, 2, figsize=(14, 10)) and set fig.suptitle('Exploratory Data Analysis', fontsize=15, fontweight='bold'). Do not use seaborn.
#
# Subplot 1 (axes[0,0]) – Event Type Distribution:
# - et_counts = space_df['event_type'].value_counts().sort_values(ascending=True)
# - Horizontal bar chart with barh(), color '#7c5cd8'
# - Add count label to right of each bar using ax.text() offset by max*0.01, va='center', fontsize=9
# - Title: 'Event Type Distribution', xlabel: 'Count'
#
# Subplot 2 (axes[0,1]) – Events per Month:
# - monthly = space_df['month'].value_counts().sort_index()
# - Bar chart, color '#3b82d4'
# - ax.set_xticks(range(1, 13)), ax.yaxis.grid(True, alpha=0.3)
# - Title: 'Events per Month', xlabel: 'Month', ylabel: 'Count'
#
# Subplot 3 (axes[1,0]) – Solar Flare Class Breakdown:
# - Filter space_df where event_type == 'Solar Flare' and flare_class != 'N/A'
# - fc_counts = flare_df['flare_class'].value_counts().sort_index()
# - class_colors dict: X->'#dc2626', M->'#f97316', C->'#eab308', B->'#22c55e'; use '#94a3b8' as default
# - Bar chart with per-bar colors list; add count labels above each bar offset by max*0.01, ha='center', fontsize=9
# - Title: 'Solar Flare Class Breakdown', xlabel: 'Flare Class', ylabel: 'Count'
#
# Subplot 4 (axes[1,1]) – Events per Year:
# - yearly = space_df['year'].value_counts().sort_index()
# - Bar chart with x-axis as yearly.index.astype(str), color '#10b981'
# - Add count labels above each bar offset by max*0.01, ha='center', fontsize=9
# - Title: 'Events per Year', xlabel: 'Year', ylabel: 'Count'
#
# Call plt.tight_layout() then plt.show(). Use only matplotlib and pandas.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === PART A: STATISTICS ===

print("=== 1. Event Type Distribution ===")
event_dist = space_df['event_type'].value_counts()
event_pct = (event_dist / len(space_df) * 100).round(2)
print(pd.DataFrame({'Count': event_dist, 'Percentage': event_pct}).to_string())

print("\n=== 2. Temporal Summary ===")
print("Events per Year:")
print(space_df['year'].value_counts().sort_index().to_string())
print("\nEvents per Month:")
print(space_df['month'].value_counts().sort_index().to_string())
print("\nEvents per Hour:")
print(space_df['hour'].value_counts().sort_index().to_string())

print("\n=== 3. Solar Flare Summary ===")
solar_flares = space_df[space_df['event_type'] == 'Solar Flare']
print(f"Total Solar Flares: {len(solar_flares):,}")
print("\nFlare Class Distribution:")
print(solar_flares['flare_class'].value_counts().to_string())
flare_mag = solar_flares[solar_flares['flare_magnitude'] > 0]['flare_magnitude']
print(f"\nFlare Magnitude — Mean: {flare_mag.mean():.2f}, Median: {flare_mag.median():.2f}, Min: {flare_mag.min():.2f}, Max: {flare_mag.max():.2f}")
flare_dur = solar_flares[solar_flares['duration_minutes'] > 0]['duration_minutes']
print(f"Duration (min)   — Mean: {flare_dur.mean():.2f}, Median: {flare_dur.median():.2f}, Min: {flare_dur.min():.2f}, Max: {flare_dur.max():.2f}")

print("\n=== 4. Geomagnetic Storm Summary ===")
geo_storms = space_df[space_df['event_type'] == 'Geomagnetic Storm']
print(f"Total Geomagnetic Storms: {len(geo_storms):,}")
print("\nStorm Class Distribution:")
print(geo_storms['class_type'].value_counts().to_string())
kp_values = geo_storms[geo_storms['kp_index'] > 0]['kp_index']
if len(kp_values) > 0:
    print(f"\nKp Index — Mean: {kp_values.mean():.2f}, Median: {kp_values.median():.2f}, Min: {kp_values.min():.2f}, Max: {kp_values.max():.2f}")
else:
    print("No Kp index data available")

# === PART B: CHARTS ===

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Exploratory Data Analysis', fontsize=15, fontweight='bold')

# Subplot 1: Event Type Distribution
ax1 = axes[0, 0]
et_counts = space_df['event_type'].value_counts().sort_values(ascending=True)
bars1 = ax1.barh(et_counts.index, et_counts.values, color='#7c5cd8')
for bar, val in zip(bars1, et_counts.values):
    ax1.text(bar.get_width() + et_counts.values.max() * 0.01,
             bar.get_y() + bar.get_height() / 2,
             f'{val:,}', va='center', fontsize=9)
ax1.set_title('Event Type Distribution')
ax1.set_xlabel('Count')

# Subplot 2: Events per Month
ax2 = axes[0, 1]
monthly = space_df['month'].value_counts().sort_index()
ax2.bar(monthly.index, monthly.values, color='#3b82d4')
ax2.set_xticks(range(1, 13))
ax2.yaxis.grid(True, alpha=0.3)
ax2.set_title('Events per Month')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')

# Subplot 3: Solar Flare Class Breakdown
ax3 = axes[1, 0]
flare_df = space_df[(space_df['event_type'] == 'Solar Flare') & (space_df['flare_class'] != 'N/A')]
fc_counts = flare_df['flare_class'].value_counts().sort_index()
class_colors = {'X': '#dc2626', 'M': '#f97316', 'C': '#eab308', 'B': '#22c55e'}
colors3 = [class_colors.get(c, '#94a3b8') for c in fc_counts.index]
bars3 = ax3.bar(fc_counts.index, fc_counts.values, color=colors3)
for bar, val in zip(bars3, fc_counts.values):
    ax3.text(bar.get_x() + bar.get_width() / 2,
             bar.get_height() + fc_counts.values.max() * 0.01,
             f'{val:,}', ha='center', fontsize=9)
ax3.set_title('Solar Flare Class Breakdown')
ax3.set_xlabel('Flare Class')
ax3.set_ylabel('Count')

# Subplot 4: Events per Year
ax4 = axes[1, 1]
yearly = space_df['year'].value_counts().sort_index()
bars4 = ax4.bar(yearly.index.astype(str), yearly.values, color='#10b981')
for bar, val in zip(bars4, yearly.values):
    ax4.text(bar.get_x() + bar.get_width() / 2,
             bar.get_height() + yearly.values.max() * 0.01,
             f'{val:,}', ha='center', fontsize=9)
ax4.set_title('Events per Year')
ax4.set_xlabel('Year')
ax4.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="task5"></a>
# ## Task 5: Add feature ngineering for risk assessment
#
# **Objective:** Transform raw space weather event data into meaningful risk features for the go/no-go decision model. Compute historical activity patterns without using future information.
#
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 5: Add feature engineering for risk assessment", and for the second cell, generate the code based on the following prompt:
#
# Import pandas as pd and timedelta from datetime. Using the cleaned pandas DataFrame space_df (from Task 3), write code that builds a new DataFrame named risk_features_df.
#
# Step 1 — Filter and sort: keep only events where space_df['date'] >= '2023-01-01'. Sort by date ascending, reset the index (drop=True), and store in sw. Convert sw['date'] to datetime using pd.to_datetime().
#
# Step 2 — For each date in sw['date'].unique(), compute these risk features using only events in sw where date >= current_date - timedelta(hours=48) AND date < current_date (strict — do NOT include the current date itself):
# - xclass_flare_count: count of rows where event_type == 'Solar Flare' and flare_class == 'X', default 0
# - mclass_flare_count: count of rows where event_type == 'Solar Flare' and flare_class == 'M', default 0
# - cclass_flare_count: count of rows where event_type == 'Solar Flare' and flare_class == 'C', default 0
# - max_kp_index: maximum of kp_index after dropna(), or 0 if empty
# - avg_kp_index: mean of kp_index after dropna(), or 0 if empty
# - storm_count: count of rows where kp_index >= 5, default 0
# - event_trend: len(last_24h) / len(prev_24h) where last_24h is events in [current_date - 24h, current_date) and prev_24h is events in [current_date - 48h, current_date - 24h); if prev_24h is empty use 1.0
#
# Step 3 — Build risk_features_df from a list of dicts with keys: date, xclass_flare_count, mclass_flare_count, cclass_flare_count, max_kp_index, avg_kp_index, storm_count, event_trend.
#
# Output:
# - Print f'Shape: {risk_features_df.shape}'
# - Return risk_features_df.head(5) as the cell's last expression (not a print, just the expression so it renders as a table)
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
import pandas as pd
from datetime import timedelta

# Filter data from 2023 onward
sw = space_df[space_df['date'] >= '2023-01-01'].sort_values('date').reset_index(drop=True)

# Convert date column to datetime if not already
sw['date'] = pd.to_datetime(sw['date'])

# Get unique dates
unique_dates = sw['date'].unique()
rows = []

for current_date in unique_dates:
    # Get events in last 48 hours
    window_start = current_date - timedelta(hours=48)
    window_data = sw[(sw['date'] >= window_start) & (sw['date'] < current_date)]

    # Count flare classes
    xclass = len(window_data[(window_data['event_type'] == 'Solar Flare') & (window_data['flare_class'] == 'X')])
    mclass = len(window_data[(window_data['event_type'] == 'Solar Flare') & (window_data['flare_class'] == 'M')])
    cclass = len(window_data[(window_data['event_type'] == 'Solar Flare') & (window_data['flare_class'] == 'C')])

    # Kp index statistics
    kp_values = window_data['kp_index'].dropna()
    max_kp = kp_values.max() if len(kp_values) > 0 else 0
    avg_kp = kp_values.mean() if len(kp_values) > 0 else 0

    # Storm count (Kp >= 5)
    storm_count = len(window_data[window_data['kp_index'] >= 5])

    # Event trend (last 24h vs previous 24h)
    last_24h = sw[(sw['date'] >= current_date - timedelta(hours=24)) & (sw['date'] < current_date)]
    prev_24h = sw[(sw['date'] >= current_date - timedelta(hours=48)) & (sw['date'] < current_date - timedelta(hours=24))]
    trend = len(last_24h) / len(prev_24h) if len(prev_24h) > 0 else 1.0

    rows.append({
        'date': current_date,
        'xclass_flare_count': xclass,
        'mclass_flare_count': mclass,
        'cclass_flare_count': cclass,
        'max_kp_index': max_kp,
        'avg_kp_index': avg_kp,
        'storm_count': storm_count,
        'event_trend': trend
    })

risk_features_df = pd.DataFrame(rows)
print(f"Shape: {risk_features_df.shape}")
risk_features_df.head(5)

# %% [markdown]
# <a id="task6"></a>
# ## Task 6: Create risk scoring model
#
# **Objective:** Build a risk scoring function that calculates launch safety scores based on recent space weather activity.
#
# **Note:** This is a simplified educational model. The weighting scheme (X-class: 40%, M-class: 25%, Kp: 20%, Trend: 15%) is designed to demonstrate the concept of multi-factor risk assessment, not to replicate operational space weather forecasting systems.
#
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 6: Create risk scoring model", and for the second cell, generate the code based on the following prompt:
#
# Using the DataFrame risk_features_df, write code to:
#
# Define a function calculate_risk_score(row) that computes a risk score (0-100) using min/max capping:
# - x_score = min(row['xclass_flare_count'] * 40, 40)
# - m_score = min(row['mclass_flare_count'] * 25, 25)
# - kp_score = (row['max_kp_index'] / 9) * 20
# - trend_score = min(max((row['event_trend'] - 1) * 15, 0), 15)
# - total = x_score + m_score + kp_score + trend_score, capped at min(total, 100)
#
# Apply with axis=1 to create risk_features_df['risk_score'].
#
# Define a function categorize_risk(score) that returns 'LOW' if score <= 20, 'MODERATE' if score <= 40, 'HIGH' if score <= 60, else 'EXTREME'. Apply to create risk_features_df['risk_level'].
#
# Print:
# - 'Risk Level Distribution:' followed by risk_level.value_counts().to_string()
# - 'Risk Score Statistics:' followed by Mean, Median, Min, Max each on its own line formatted to 2 decimals
# - 'Top 5 Highest Risk Dates:' followed by the top 5 rows (by risk_score) showing columns date, risk_score, risk_level printed with .to_string()
#
# Finally return risk_features_df.head(10) as the cell's last expression so it renders as a table.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
def calculate_risk_score(row):
    # X-class contribution (max 40)
    x_score = min(row['xclass_flare_count'] * 40, 40)

    # M-class contribution (max 25)
    m_score = min(row['mclass_flare_count'] * 25, 25)

    # Kp index contribution (max 20)
    kp_score = (row['max_kp_index'] / 9) * 20

    # Trend contribution (max 15)
    trend_score = max((row['event_trend'] - 1) * 15, 0)
    trend_score = min(trend_score, 15)

    total = x_score + m_score + kp_score + trend_score
    return min(total, 100)

# Apply risk scoring
risk_features_df['risk_score'] = risk_features_df.apply(calculate_risk_score, axis=1)

# Categorize risk levels
def categorize_risk(score):
    if score <= 20:
        return 'LOW'
    elif score <= 40:
        return 'MODERATE'
    elif score <= 60:
        return 'HIGH'
    else:
        return 'EXTREME'

risk_features_df['risk_level'] = risk_features_df['risk_score'].apply(categorize_risk)

# Print statistics
print("Risk Level Distribution:")
print(risk_features_df['risk_level'].value_counts().to_string())

print("\nRisk Score Statistics:")
print(f"Mean: {risk_features_df['risk_score'].mean():.2f}")
print(f"Median: {risk_features_df['risk_score'].median():.2f}")
print(f"Min: {risk_features_df['risk_score'].min():.2f}")
print(f"Max: {risk_features_df['risk_score'].max():.2f}")

print("\nTop 5 Highest Risk Dates:")
print(risk_features_df.nlargest(5, 'risk_score')[['date', 'risk_score', 'risk_level']].to_string())

risk_features_df.head(10)

# %% [markdown]
# <a id="task7"></a>
# ## Task 7: Train and evaluate decision model
#
# **Objective:** Train a classification model to predict launch recommendations (GO/NO-GO) based on space weather features.
#
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 7: Train and evaluate decision model", and for the second cell, generate the code based on the following prompt:
#
# Import pandas as pd, RandomForestClassifier from sklearn.ensemble, and accuracy_score and classification_report from sklearn.metrics. Using risk_features_df, write code to:
#
# Define feature_cols as: ['xclass_flare_count', 'mclass_flare_count', 'cclass_flare_count', 'max_kp_index', 'avg_kp_index', 'storm_count', 'event_trend']
#
# Split data using a cutoff = pd.Timestamp('2025-01-01'): training set is rows where date < cutoff, test set is rows where date >= cutoff. Build X_train, X_test as DataFrames of feature_cols, and y_train, y_test as Series of the risk_level column.
#
# Print f'X_train: {X_train.shape}, X_test: {X_test.shape}' and f'y_train: {y_train.shape}, y_test: {y_test.shape}'.
#
# Create model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42, n_jobs=-1). Fit on X_train/y_train. Compute y_pred = model.predict(X_test).
#
# Print:
# - f'Test accuracy: {acc*100:.2f}%' (preceded by a blank line)
# - 'Classification Report:' followed by classification_report(y_test, y_pred)
# - 'Feature Importances:' followed by each (feature_name, importance) pair sorted descending by importance, one per line formatted as '  {name:<25} {imp:.4f}'
#
# Do not use cross-validation.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Define features
feature_cols = ['xclass_flare_count', 'mclass_flare_count', 'cclass_flare_count',
                'max_kp_index', 'avg_kp_index', 'storm_count', 'event_trend']

# Time-based split
cutoff = pd.Timestamp('2025-01-01')
train_mask = risk_features_df['date'] < cutoff
test_mask = risk_features_df['date'] >= cutoff

X_train = risk_features_df.loc[train_mask, feature_cols]
X_test = risk_features_df.loc[test_mask, feature_cols]
y_train = risk_features_df.loc[train_mask, 'risk_level']
y_test = risk_features_df.loc[test_mask, 'risk_level']

print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")

# Train model
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42, n_jobs=-1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Evaluate
acc = accuracy_score(y_test, y_pred)
print(f"\nTest accuracy: {acc*100:.2f}%")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nFeature Importances:")
for name, imp in sorted(zip(feature_cols, model.feature_importances_), key=lambda x: -x[1]):
    print(f"  {name:<25} {imp:.4f}")

# %% [markdown]
# <a id="task8"></a>
# ## Task 8: Save model and risk data
#
# **Objective:** Save the trained model and current space weather statistics for use in the dashboard application.
#
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **🎉 Task Completed** section to understand what the generated code does.

# %% [markdown]
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 8: Save model and risk data", and for the second cell, generate the code based on the following prompt:
#
# Import Path from pathlib and joblib. Using the trained model, risk_features_df, and feature_cols, write code to:
#
# Create models/ directory via Path('models').mkdir(exist_ok=True).
#
# Get latest_row = risk_features_df.iloc[-1]. Build current_stats dict with:
# - 'latest_date': latest_row['date']
# - 'latest_risk_score': latest_row['risk_score']
# - 'latest_risk_level': latest_row['risk_level']
# - 'xclass_48h': int(latest_row['xclass_flare_count'])
# - 'mclass_48h': int(latest_row['mclass_flare_count'])
# - 'max_kp_48h': float(latest_row['max_kp_index'])
# - 'recommendation': inline conditional — 'GO' if risk_level == 'LOW', 'CAUTION' if 'MODERATE', 'DELAY' if 'HIGH', else 'NO-GO'
#
# Save model to models/launch_decision_model.pkl via joblib.dump(model, models_dir / 'launch_decision_model.pkl').
#
# Build data_package = {'current_stats': current_stats, 'feature_cols': feature_cols, 'risk_features': risk_features_df.tail(30).to_dict('records')} and save to models/space_weather_data.pkl via joblib.dump.
#
# Print:
# - '=' * 60 separator line
# - 'SPACE WEATHER LAUNCH SAFETY SYSTEM'
# - '=' * 60 separator line
# - blank line then f'Current Date: {current_stats["latest_date"]}'
# - f'Risk Score: {current_stats["latest_risk_score"]:.1f}/100'
# - f'Risk Level: {current_stats["latest_risk_level"]}'
# - blank line then f'🚀 LAUNCH RECOMMENDATION: {current_stats["recommendation"]}'
# - blank line then 'Key Metrics (Last 48 hours):'
# - f'  X-class flares: {current_stats["xclass_48h"]}'
# - f'  M-class flares: {current_stats["mclass_48h"]}'
# - f'  Max Kp index: {current_stats["max_kp_48h"]:.1f}'
# - blank line then '✅ Model saved to: models/launch_decision_model.pkl'
# - '✅ Data saved to: models/space_weather_data.pkl'
#
# Use only pathlib and joblib.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Compare the output with Bob's code — both should be nearly identical.

# %%
from pathlib import Path
import joblib

# Create models directory
models_dir = Path("models")
models_dir.mkdir(exist_ok=True)

# Compute current statistics
latest_row = risk_features_df.iloc[-1]
current_stats = {
    'latest_date': latest_row['date'],
    'latest_risk_score': latest_row['risk_score'],
    'latest_risk_level': latest_row['risk_level'],
    'xclass_48h': int(latest_row['xclass_flare_count']),
    'mclass_48h': int(latest_row['mclass_flare_count']),
    'max_kp_48h': float(latest_row['max_kp_index']),
    'recommendation': 'GO' if latest_row['risk_level'] == 'LOW' else
                     'CAUTION' if latest_row['risk_level'] == 'MODERATE' else
                     'DELAY' if latest_row['risk_level'] == 'HIGH' else 'NO-GO'
}

# Save model
joblib.dump(model, models_dir / "launch_decision_model.pkl")

# Save data
data_package = {
    'current_stats': current_stats,
    'feature_cols': feature_cols,
    'risk_features': risk_features_df.tail(30).to_dict('records')
}
joblib.dump(data_package, models_dir / "space_weather_data.pkl")

# Print summary
print("=" * 60)
print("SPACE WEATHER LAUNCH SAFETY SYSTEM")
print("=" * 60)
print(f"\nCurrent Date: {current_stats['latest_date']}")
print(f"Risk Score: {current_stats['latest_risk_score']:.1f}/100")
print(f"Risk Level: {current_stats['latest_risk_level']}")
print(f"\n🚀 LAUNCH RECOMMENDATION: {current_stats['recommendation']}")
print("\nKey Metrics (Last 48 hours):")
print(f"  X-class flares: {current_stats['xclass_48h']}")
print(f"  M-class flares: {current_stats['mclass_48h']}")
print(f"  Max Kp index: {current_stats['max_kp_48h']:.1f}")
print("\n✅ Model saved to: models/launch_decision_model.pkl")
print("✅ Data saved to: models/space_weather_data.pkl")

# %% [markdown]
# <a id="task9"></a>
# ## Task 9: Build a date-range go/no-go dashboard
#
# **Objective:** Build a dashboard with matplotlib that lets you pick any date range from the saved risk data and see the day-by-day go/no-go analysis, risk score trend, and solar event breakdown for that window.
#
# ### Prompt for Bob
#
# 1. Copy and paste the following prompt into Bob's chat panel in *Agent* mode.
# 1. To confirm permission to complete the tasks, click **Approve once** when prompted by Bob.
# 1. Read through the **Task Completed** section to understand what the generated code does.

# %% [markdown]
# ### Bob prompt
#
# ```
# At end of the bob_generated_code.ipynb Jupyter notebook file, add two cells. The first cell is a heading with "Task 9: Build a date-range go/no-go dashboard", and for the second cell, generate the code based on the following prompt:
#
# Import joblib, pandas as pd, and matplotlib.pyplot as plt. Write a self-contained Jupyter cell that:
#
# 1. Defines START_DATE = '2025-05-01' and END_DATE = '2025-07-09' as strings at the very top of the cell with a comment '# ── Edit these two variables to change the analysis window ─────────────────'.
#
# 2. Loads pkg = joblib.load('models/space_weather_data.pkl'), builds dash_df = pd.DataFrame(pkg['risk_features']), and converts dash_df['date'] to datetime.
#
# 3. Filters dash_df to window_df where date >= pd.Timestamp(START_DATE) and date <= pd.Timestamp(END_DATE), reset_index(drop=True).
#
# 4. Defines rec_map = {'LOW': 'GO', 'MODERATE': 'CAUTION', 'HIGH': 'DELAY', 'EXTREME': 'NO-GO'}. Computes dominant_level = window_df['risk_level'].mode()[0] if len(window_df) else 'LOW'. Computes max_idx = window_df['risk_score'].idxmax() if len(window_df) else 0. Builds window_summary dict with:
#    - 'total_days': len(window_df)
#    - 'avg_risk_score': round(window_df['risk_score'].mean(), 2) if len(window_df) else 0
#    - 'go_days': int((window_df['risk_level'] == 'LOW').sum())
#    - 'caution_days': int((window_df['risk_level'] == 'MODERATE').sum())
#    - 'delay_days': int((window_df['risk_level'] == 'HIGH').sum())
#    - 'nogo_days': int((window_df['risk_level'] == 'EXTREME').sum())
#    - 'overall_recommendation': rec_map[dominant_level]
#    - 'max_risk_score': float(window_df['risk_score'].max()) if len(window_df) else 0
#    - 'max_risk_date': str(window_df.loc[max_idx, 'date'])[:10] if len(window_df) else 'N/A'
#
# 5. Prints this exact formatted summary:
#    f'=== Go/No-Go Analysis: {START_DATE} to {END_DATE} ==='
#    f'Overall Recommendation : {window_summary["overall_recommendation"]}'
#    f'Days analysed          : {window_summary["total_days"]}'
#    f'Avg risk score         : {window_summary["avg_risk_score"]:.2f} / 100'
#    f'GO days                : {window_summary["go_days"]}'
#    f'CAUTION days           : {window_summary["caution_days"]}'
#    f'DELAY days             : {window_summary["delay_days"]}'
#    f'NO-GO days             : {window_summary["nogo_days"]}'
#    f'Highest risk date      : {window_summary["max_risk_date"]}  (score {window_summary["max_risk_score"]:.1f})'
#
# 6. If len(window_df) == 0, print 'No data in selected window.' and stop. Otherwise:
#    - Build color_map = {'LOW': '#22c55e', 'MODERATE': '#f59e0b', 'HIGH': '#f97316', 'EXTREME': '#dc2626'}
#    - bar_colors = window_df['risk_level'].map(color_map).tolist()
#    - dates = window_df['date'].dt.strftime('%Y-%m-%d').tolist()
#    - Create fig, axes = plt.subplots(3, 1, figsize=(14, 10))
#    - fig.suptitle(f'Space Weather Go/No-Go Dashboard  |  {START_DATE} to {END_DATE}', fontsize=14, fontweight='bold')
#
#    Subplot 1 (axes[0]) — Risk Score per Day:
#    - ax1.bar(dates, window_df['risk_score'], color=bar_colors, width=0.6)
#    - ax1.axhline(20, color='#57606a', linestyle='--', linewidth=1, label='GO threshold (20)')
#    - ax1.axhline(60, color='#57606a', linestyle=':', linewidth=1, label='NO-GO threshold (60)')
#    - Title 'Risk Score per Day', ylabel 'Risk Score (0-100)', ylim(0, 105)
#    - ax1.set_xticks(range(len(dates))), xticklabels rotated 45°, ha='right', fontsize=8
#    - ax1.legend(fontsize=8), ax1.yaxis.grid(True, alpha=0.3)
#
#    Subplot 2 (axes[1]) — Daily Recommendation:
#    - level_num = window_df['risk_level'].map({'LOW': 1, 'MODERATE': 2, 'HIGH': 3, 'EXTREME': 4}).tolist()
#    - ax2.bar(dates, level_num, color=bar_colors, width=0.6)
#    - ax2.set_yticks([1,2,3,4]), yticklabels ['GO','CAUTION','DELAY','NO-GO']
#    - Title 'Daily Recommendation', ylim(0, 5)
#    - x-ticks same as subplot 1, ax2.yaxis.grid(True, alpha=0.3)
#
#    Subplot 3 (axes[2]) — Solar Events in 48h Window (stacked bars):
#    - ax3.bar(dates, xclass_flare_count, color='#dc2626', width=0.6, label='X-class')
#    - ax3.bar(dates, mclass_flare_count, color='#f97316', width=0.6, label='M-class', bottom=xclass_flare_count)
#    - ax3.bar(dates, cclass_flare_count, color='#eab308', width=0.6, label='C-class', bottom=xclass+mclass)
#    - ax3.bar(dates, storm_count, color='#7c5cd8', width=0.6, label='Storms', bottom=xclass+mclass+cclass)
#    - Title 'Solar Events in 48h Window', xlabel 'Date', ylabel 'Event Count'
#    - x-ticks same as subplot 1, ax3.legend(fontsize=8), ax3.yaxis.grid(True, alpha=0.3)
#
#    Call plt.tight_layout() then plt.show(). Use only pandas, joblib, and matplotlib. Do not use seaborn.
# ```

# %% [markdown]
# ### Execute Bob's code
#
# 1. View the bob_generated_code.ipynb file.
# 1. In the Jupyter Lab menu, click **File > Reload Notebook from Disk**.
# 1. If prompted, click **Reload** to confirm.
# 1. Copy the code generated by Bob into the empty cell and run the code in the cell.
# 1. If you encounter errors, copy the error message back to Bob to get corrected code.
# 1. Alternatively, execute the code in the fallback code cell to see the expected output.
# 1. To change the date window, edit **START_DATE** and **END_DATE** at the top of the cell and re-run.

# %% [markdown]
# ### Fallback code
#
# Use this code if Bob's output does not work. Edit **START_DATE** and **END_DATE** at the top of the cell to change the analysis window.

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt

# ── Edit these two variables to change the analysis window ─────────────────
START_DATE = '2025-05-01'
END_DATE   = '2025-07-09'
# ───────────────────────────────────────────────────────────────────────────

# Load saved data
pkg = joblib.load('models/space_weather_data.pkl')
dash_df = pd.DataFrame(pkg['risk_features'])
dash_df['date'] = pd.to_datetime(dash_df['date'])

# Filter to selected window
window_df = dash_df[
    (dash_df['date'] >= pd.Timestamp(START_DATE)) &
    (dash_df['date'] <= pd.Timestamp(END_DATE))
].reset_index(drop=True)

# Compute window summary
rec_map = {'LOW': 'GO', 'MODERATE': 'CAUTION', 'HIGH': 'DELAY', 'EXTREME': 'NO-GO'}
dominant_level = window_df['risk_level'].mode()[0] if len(window_df) else 'LOW'
max_idx = window_df['risk_score'].idxmax() if len(window_df) else 0
window_summary = {
    'total_days':             len(window_df),
    'avg_risk_score':         round(window_df['risk_score'].mean(), 2) if len(window_df) else 0,
    'go_days':                int((window_df['risk_level'] == 'LOW').sum()),
    'caution_days':           int((window_df['risk_level'] == 'MODERATE').sum()),
    'delay_days':             int((window_df['risk_level'] == 'HIGH').sum()),
    'nogo_days':              int((window_df['risk_level'] == 'EXTREME').sum()),
    'overall_recommendation': rec_map[dominant_level],
    'max_risk_score':         float(window_df['risk_score'].max()) if len(window_df) else 0,
    'max_risk_date':          str(window_df.loc[max_idx, 'date'])[:10] if len(window_df) else 'N/A',
}

# Print summary
print(f"=== Go/No-Go Analysis: {START_DATE} to {END_DATE} ===")
print(f"Overall Recommendation : {window_summary['overall_recommendation']}")
print(f"Days analysed          : {window_summary['total_days']}")
print(f"Avg risk score         : {window_summary['avg_risk_score']:.2f} / 100")
print(f"GO days                : {window_summary['go_days']}")
print(f"CAUTION days           : {window_summary['caution_days']}")
print(f"DELAY days             : {window_summary['delay_days']}")
print(f"NO-GO days             : {window_summary['nogo_days']}")
print(f"Highest risk date      : {window_summary['max_risk_date']}  (score {window_summary['max_risk_score']:.1f})")

if len(window_df) == 0:
    print('\nNo data in selected window.')
else:
    color_map = {'LOW': '#22c55e', 'MODERATE': '#f59e0b', 'HIGH': '#f97316', 'EXTREME': '#dc2626'}
    bar_colors = window_df['risk_level'].map(color_map).tolist()
    dates = window_df['date'].dt.strftime('%Y-%m-%d').tolist()

    fig, axes = plt.subplots(3, 1, figsize=(14, 10))
    fig.suptitle(
        f'Space Weather Go/No-Go Dashboard  |  {START_DATE} to {END_DATE}',
        fontsize=14, fontweight='bold'
    )

    # Subplot 1: Risk Score Trend
    ax1 = axes[0]
    ax1.bar(dates, window_df['risk_score'], color=bar_colors, width=0.6)
    ax1.axhline(20, color='#57606a', linestyle='--', linewidth=1, label='GO threshold (20)')
    ax1.axhline(60, color='#57606a', linestyle=':',  linewidth=1, label='NO-GO threshold (60)')
    ax1.set_title('Risk Score per Day')
    ax1.set_ylabel('Risk Score (0-100)')
    ax1.set_ylim(0, 105)
    ax1.set_xticks(range(len(dates)))
    ax1.set_xticklabels(dates, rotation=45, ha='right', fontsize=8)
    ax1.legend(fontsize=8)
    ax1.yaxis.grid(True, alpha=0.3)

    # Subplot 2: Daily Recommendation
    ax2 = axes[1]
    level_num = window_df['risk_level'].map({'LOW': 1, 'MODERATE': 2, 'HIGH': 3, 'EXTREME': 4}).tolist()
    ax2.bar(dates, level_num, color=bar_colors, width=0.6)
    ax2.set_yticks([1, 2, 3, 4])
    ax2.set_yticklabels(['GO', 'CAUTION', 'DELAY', 'NO-GO'])
    ax2.set_title('Daily Recommendation')
    ax2.set_ylim(0, 5)
    ax2.set_xticks(range(len(dates)))
    ax2.set_xticklabels(dates, rotation=45, ha='right', fontsize=8)
    ax2.yaxis.grid(True, alpha=0.3)

    # Subplot 3: Solar Event Counts (stacked)
    ax3 = axes[2]
    ax3.bar(dates, window_df['xclass_flare_count'], color='#dc2626', width=0.6, label='X-class')
    ax3.bar(dates, window_df['mclass_flare_count'], color='#f97316', width=0.6, label='M-class',
            bottom=window_df['xclass_flare_count'])
    ax3.bar(dates, window_df['cclass_flare_count'], color='#eab308', width=0.6, label='C-class',
            bottom=window_df['xclass_flare_count'] + window_df['mclass_flare_count'])
    ax3.bar(dates, window_df['storm_count'], color='#7c5cd8', width=0.6, label='Storms',
            bottom=window_df['xclass_flare_count'] + window_df['mclass_flare_count'] + window_df['cclass_flare_count'])
    ax3.set_title('Solar Events in 48h Window')
    ax3.set_xlabel('Date')
    ax3.set_ylabel('Event Count')
    ax3.set_xticks(range(len(dates)))
    ax3.set_xticklabels(dates, rotation=45, ha='right', fontsize=8)
    ax3.legend(fontsize=8)
    ax3.yaxis.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()
